# %%
import pandas as pd

# %%
local = pd.read_csv('merged_for_comparison.csv')
colab = pd.read_csv('merged_from_colab.csv')

# %%
local_noname = local.drop(columns='name')
colab_noname = colab.drop(columns='name')

# %%
for c in local_noname.columns:
    print(
        (
            ((local_noname[c] == colab_noname[c]))
            | (local_noname[c].isna() & colab_noname[c].isna())
        ).sum()
    )
# Out:
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 29
# 50
# 13
# 4
# 50
# 50
# 50
# 29
# 50
# 11
# 11
# 50
# 50
# 50
# 29
# 50
# 16
# 9
# 50
# 50
# 50
# 28
# 50
# 8
# 6
# 50
# 50
# 50
# 36
# 50
# 12
# 8
# 50
# 50
# 50
# 30
# 50
# 14
# 12
# 50
# 50
# 50
# 35
# 50
# 12
# 12
# 50
# 50
# 50
# 35
# 50
# 5
# 15
# 50
# 50
# 50
# 40
# 50
# 5
# 14
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 30
# 38
# 43
# 44
# 46
# 44
# 36
# 41
# 45
# 45
# 46
# 44
# 48
# ...

# %%
colab_noname.call_duration_allweek_allday_call_mean
# Out:
# 0     160.478723
# 1     144.833333
# 2     144.404255
# 3     155.272727
# 4     145.651685
# 5     140.822430
# 6     150.979381
# 7     152.549451
# 8     158.351064
# 9     167.291667
# 10    161.506024
# 11    135.487805
# 12    145.063636
# 13    137.479167
# 14    142.377193
# 15    163.170455
# 16    140.971154
# 17    146.190476
# 18    153.808511
# 19    137.649351
# 20    149.395349
# 21    146.725275
# 22    150.386364
# 23    146.875000
# 24    141.562500
# 25    143.871287
# 26    150.184783
# 27    139.128205
# 28    159.048193
# 29    172.765432
# 30    150.346939
# 31    152.186813
# 32    144.395604
# 33    154.614458
# 34    147.643564
# 35    154.597701
# 36    143.520408
# 37    150.170455
# 38    139.048077
# 39    157.012821
# 40    146.979798
# 41    148.265957
# 42    155.028846
# 43    136.635294
# 44    143.440860
# 45    146.240000
# 46    156.776786
# 47    157.239583
# 48    155.920000
# 49    153.524272
# ...
